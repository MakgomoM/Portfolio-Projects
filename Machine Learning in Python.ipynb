# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

music_data = pd.read_csv('music.csv')

#Training/Test sets
X = music_data.drop(columns = ['genre']) 
y = music_data['genre']

#Building the model
model = DecisionTreeClassifier()
model.fit(X,y)

# Music Genre Prediction for a 21 year-old male and 22 year-old female
predictions = model.predict([[21, 1],[22, 0]])
predictions
# Out:
# C:\Users\nrmog\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

music_data = pd.read_csv('music.csv')

#Training/Test sets
X = music_data.drop(columns = ['genre']) 
y = music_data['genre']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

#Building the model
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
predictions = model.predict(X_test)

#Calculating the accuracy of the model
score = accuracy_score(y_test, predictions)
score
# Out:
# 0.75

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

# music_data = pd.read_csv('music.csv')

# #Training/Test sets
# X = music_data.drop(columns = ['genre']) 
# y = music_data['genre']

# #Building the model
# model = DecisionTreeClassifier()
# model.fit(X,y)

# joblib.dump(model,'music-recommender.joblib')


model = joblib.load('music-recommender.joblib')

predictions = model.predict([[22, 1],[22, 0]])
predictions
# Out:
# C:\Users\nrmog\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
#Decision Tree
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from sklearn import tree
# !pip install graphviz
# import graphviz

music_data = pd.read_csv('music.csv')
X = music_data.drop(columns = ['genre']) 
y = music_data['genre']

model = DecisionTreeClassifier()
model.fit(X,y)

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model, feature_names=['age', 'gender'], class_names = sorted(y.unique()),label = 'all', filled=True)
